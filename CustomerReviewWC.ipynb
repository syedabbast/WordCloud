# %% [markdown]
# <a href="https://colab.research.google.com/github/syedabbast/WordCloud/blob/main/CustomerReviewWC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
import re

# %%
# Load the data from CSV file
df = pd.read_csv('/content/drive/MyDrive/customer_reviews.csv')

# %%
print(df)
# Out:
#                                                  Review
# 0     I had such high hopes for this dress and reall...
# 1     I love, love, love this jumpsuit. it's fun, fl...
# 2     I love tracy reese dresses, but this one is no...
# 3     Dress runs small esp where the zipper area run...
# 4     This dress is perfection! so pretty and flatte...
# ...                                                 ...
# 5995  I wore this dress to work the other day and go...
# 5996  I worry when i have an elastic waist, or somet...
# 5997  Love the way these pants look in the pictures,...
# 5998  I was surprised at the positive reviews for th...
# 5999  This fit well, but the top was very see throug...
#
# [6000 rows x 1 columns]

# %%
# Concatenate all reviews into a single string
text = " ".join(review for review in df['Review'])

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Clean the text data
stopwords = set(stopwords.words('english'))
text = re.sub('[^A-Za-z]+', ' ', text)
words = text.split()
clean_text = [word for word in words if word.lower() not in stopwords]
clean_text = ' '.join(clean_text)

# %%
# Generate the word cloud
wc = WordCloud(width=800, height=400, background_color='white').generate(clean_text)

# %%
# Display the word cloud using matplotlib
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
